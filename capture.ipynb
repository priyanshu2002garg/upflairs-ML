# %%
import cv2
import matplotlib.pyplot as plt

# %%
vid=cv2.VideoCapture(0)

# %%
type(vid)
# Out:
# cv2.VideoCapture

# %%
vid.isOpened()
# Out:
# True

# %%
k=vid.read()

# %%
type(k),len(k)
# Out:
# (tuple, 2)

# %%
k
# Out:
# (True,
#  array([[[ 52, 131, 144],
#          [ 52, 131, 143],
#          [ 53, 133, 144],
#          ...,
#          [ 43, 137, 153],
#          [ 24, 140, 152],
#          [ 24, 140, 152]],
#
#         [[ 50, 130, 137],
#          [ 49, 129, 136],
#          [ 50, 130, 137],
#          ...,
#          [ 44, 138, 151],
#          [ 29, 140, 150],
#          [ 29, 140, 150]],
#
#         [[ 52, 134, 129],
#          [ 51, 132, 130],
#          [ 52, 132, 133],
#          ...,
#          [ 47, 140, 150],
#          [ 41, 141, 148],
#          [ 41, 141, 148]],
#
#         ...,
#
#         [[ 22,  36, 127],
#          [ 31,  47, 145],
#          [ 45,  63, 168],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[ 18,  34, 127],
#          [ 24,  49, 144],
#          [ 40,  74, 171],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[ 21,  38, 132],
# ...

# %%
k
# Out:
# (True,
#  array([[[ 52, 131, 144],
#          [ 52, 131, 143],
#          [ 53, 133, 144],
#          ...,
#          [ 43, 137, 153],
#          [ 24, 140, 152],
#          [ 24, 140, 152]],
#
#         [[ 50, 130, 137],
#          [ 49, 129, 136],
#          [ 50, 130, 137],
#          ...,
#          [ 44, 138, 151],
#          [ 29, 140, 150],
#          [ 29, 140, 150]],
#
#         [[ 52, 134, 129],
#          [ 51, 132, 130],
#          [ 52, 132, 133],
#          ...,
#          [ 47, 140, 150],
#          [ 41, 141, 148],
#          [ 41, 141, 148]],
#
#         ...,
#
#         [[ 22,  36, 127],
#          [ 31,  47, 145],
#          [ 45,  63, 168],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[ 18,  34, 127],
#          [ 24,  49, 144],
#          [ 40,  74, 171],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[ 21,  38, 132],
# ...

# %%
m=(3,4)

# %%
m,n=(3,4)

# %%
flag,img=vid.read()

# %%
flag
# Out:
# True

# %%
img
# Out:
# array([[[ 35,  23,  63],
#         [ 37,  28,  69],
#         [ 41,  33,  77],
#         ...,
#         [255, 255, 255],
#         [255, 255, 252],
#         [253, 254, 247]],
#
#        [[ 34,  26,  64],
#         [ 38,  32,  71],
#         [ 41,  36,  78],
#         ...,
#         [255, 255, 255],
#         [255, 255, 254],
#         [255, 255, 251]],
#
#        [[ 34,  33,  65],
#         [ 36,  37,  72],
#         [ 39,  41,  79],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 253]],
#
#        ...,
#
#        [[  3,   2,   3],
#         [  5,   3,   4],
#         [  5,   3,   4],
#         ...,
#         [ 58,  70,  58],
#         [ 60,  73,  62],
#         [ 63,  76,  64]],
#
#        [[  2,   4,   3],
#         [  2,   4,   3],
#         [  2,   4,   3],
#         ...,
#         [ 50,  69,  42],
#         [ 54,  72,  45],
#         [ 55,  74,  46]],
#
#        [[  0,   3,   1],
#         [  0,   3,   1],
#         [  1,   4,   2],
# ...

# %%
if flag:
    plt.imshow(img)

# %%
if flag:
    plt.imshow(img)

# %%
if flag:
    plt.imshow(img)

# %%
flag,img=vid.read()

# %%
if flag:
    plt.imshow(img)

# %%
flag,img=vid.read()

# %%
if flag:
    plt.imshow(img)
